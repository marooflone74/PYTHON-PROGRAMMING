# %% [markdown]
# Question 1: Code Along
# Problem: Write a Python program that takes a string as input and prints out the
# following:
# 1. The string in reverse order.
# 2. The number of vowels in the string.
# Instructions:
# ● Use basic string manipulation techniques such as loops, conditionals, and
# string methods.
# ● Ensure that the program counts both uppercase and lowercase vowels (a, e,
# i, o, u).

# %%
# Problem: Write a Python program that takes a string as input and prints out the
# following:
# 1. The string in reverse order.
# 2. The number of vowels in the string.
# Instructions:
# ● Use basic string manipulation techniques such as loops, conditionals, and
# string methods.
# ● Ensure that the program counts both uppercase and lowercase vowels (a, e,
# i, o, u).

string = input("Enter a string: ")
# Reverse the string
reversed_string = string[::-1]
# Count the number of vowels
vowel_count = 0
vowels = "aeiouAEIOU"
for char in string:
    if char in vowels:
        vowel_count += 1
# Print the results
print("Reversed string:", reversed_string)
print("Number of vowels:", vowel_count)
# Out:
# Reversed string: repoleved nohtyp,olleh
# Number of vowels: 7

# %%
# QNO2:
# Problem: Create a Python program that:
# ● Takes an input number from the user.
# ● Checks whether the number is even or odd.
# ● Prints the result.
# Instructions:
# ● Write a Python script that accepts a number from the user, determines
# whether it is even or odd, and prints the result.
# ● Use conditionals to check if the number is even or odd.

number = int(input("Enter a number: "))
if number % 2==0:
    print(f"{number} is an even number.")
else:
    print(f"{number} is an odd number.")
# Out:
# 76 is an even number.

# %%
# Question 3: Virtual Environment Application
# Problem: Create a Python program that:
# 1. Takes a list of integers as input.
# 2. Creates a new virtual environment called sortenv.
# 3. Installs a package (such as numpy) in the virtual environment.
# 4. Sorts the list using a numpy method (numpy.sort()).
# 5. Prints the sorted list.
# Instructions:
# ● You will not be expected to actually run the environment creation commands
# but rather simulate what would happen by describing the steps in your code
# and then focusing on the sorting operation.
# ● Make sure that your program explains each step as comments and performs
# sorting using numpy.

# Step 1: Take a list of integers as input
input_string = input("Enter a list of integers separated by spaces: ")
# Convert the input string into a list of integers
integer_list = list(map(int, input_string.split())) # This line takes the input string, splits it into individual components based on spaces, and then converts each component into an integer using the map function. The resulting map object is then converted into a list of integers.
# Step 2: Create a new virtual environment called sortenv
# (In a real scenario, you would run the command: python -m venv sortenv)
# Step 3: Install a package (such as numpy) in the virtual environment
# (In a real scenario, you would activate the virtual environment and run: pip install numpy
# Step 4: Sort the list using a numpy method (numpy.sort())
import numpy as np
sorted_list = np.sort(integer_list)
unsorted_list = np.sort_complex(integer_list)
# Step 5: Print the sorted list
print("Sorted list:", sorted_list) # Output will be a sorted list of integers entered by the user.

print("unsorted_list:",unsorted_list)
# Out:
# Sorted list: [   3    5   56   79  100 1099]
# unsorted_list: [   3.+0.j    5.+0.j   56.+0.j   79.+0.j  100.+0.j 1099.+0.j]
